# %%
import pandas as pd

# %%
df = pd.read_csv('dadosCGETratados.csv')
df
# Out:
#            Data        Zona       Bairro  Ponto                 Status  \
# 0    2023-09-02      Centro           Sé      1  Inativo Intransitável
# 1    2023-09-02  Zona Oeste         Lapa      2    Inativo Transitável
# 2    2023-09-02  Zona Oeste         Lapa      2  Inativo Intransitável
# 3    2023-09-02    Zona Sul  Santo Amaro      1  Inativo Intransitável
# 4    2023-09-03  Zona Leste     Itaquera      1  Inativo Intransitável
# ..          ...         ...          ...    ...                    ...
# 637  2024-07-10      Centro           Sé      5  Inativo Intransitável
# 638  2024-07-10      Centro           Sé      5  Inativo Intransitável
# 639  2024-07-10      Centro           Sé      5  Inativo Intransitável
# 640  2024-07-10      Centro           Sé      5  Inativo Intransitável
# 641  2024-07-10  Zona Oeste    Pinheiros      1    Inativo Transitável
#
#                      Sentido                Referencia HorarioInicio  \
# ...

# %%
df['Zona'].unique()
# Out:
# array(['Centro', 'Zona Oeste', 'Zona Sul', 'Zona Leste', 'Zona Norte',
#        'Zona Sudeste'], dtype=object)

# %%
df[df['Zona']=='Zona Sudeste']['Bairro'].unique()
# Out:
# array(['Ipiranga', 'Jabaquara', 'Vila Mariana'], dtype=object)

# %%
for i in range(len(df)):
  if df['Zona'][i] == 'Zona Sudeste':
    df['Zona'][i] = 'Zona Sul'
# Out:
# <ipython-input-42-dddc6a804b00>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Zona'][i] = 'Zona Sul'
# <ipython-input-42-dddc6a804b00>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Zona'][i] = 'Zona Sul'
# <ipython-input-42-dddc6a804b00>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Zona'][i] = 'Zona Sul'
# <ipython-input-42-dddc6a804b00>:3: SettingWithCopyWarning:
# ...

# %%
df[df['Zona']=='Zona Sul']['Bairro'].unique()
# Out:
# array(['Santo Amaro', 'Ipiranga', 'Capela do Socorro', 'Jabaquara',
#        'Vila Mariana', 'Campo Limpo', "M'Boi Mirim", 'Cidade Ademar',
#        'Parelheiros'], dtype=object)

# %%
df['Zona'].unique()
# Out:
# array(['Centro', 'Zona Oeste', 'Zona Sul', 'Zona Leste', 'Zona Norte'],
#       dtype=object)

# %%
dfZonaSul = df[df['Zona']=='Zona Sul']
dfZonaSul
# Out:
#            Data      Zona             Bairro  Ponto                 Status  \
# 3    2023-09-02  Zona Sul        Santo Amaro      1  Inativo Intransitável
# 10   2023-09-30  Zona Sul        Santo Amaro      1    Inativo Transitável
# 29   2023-10-01  Zona Sul        Santo Amaro      2    Inativo Transitável
# 30   2023-10-01  Zona Sul        Santo Amaro      2    Inativo Transitável
# 31   2023-10-01  Zona Sul           Ipiranga      1    Inativo Transitável
# ..          ...       ...                ...    ...                    ...
# 578  2024-03-08  Zona Sul       Vila Mariana      2    Inativo Transitável
# 579  2024-03-08  Zona Sul       Vila Mariana      2    Inativo Transitável
# 589  2024-03-18  Zona Sul  Capela do Socorro      1    Inativo Transitável
# 630  2024-05-27  Zona Sul       Vila Mariana      1    Inativo Transitável
# 634  2024-07-09  Zona Sul        Campo Limpo      1    Inativo Transitável
#
# ...

# %%
dfZonaSul.to_csv('dadosCGEZonaSul.csv', encoding='UTF-8', index=False)
