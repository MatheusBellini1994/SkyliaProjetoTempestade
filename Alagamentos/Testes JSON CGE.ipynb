# %%
import pandas as pd

# %%
df = pd.DataFrame()

# %%
date = ['2023-09-02']

# %%
data = ["[{'zona': 'Centro', 'info': {'bairro': 'Sé', 'ponto': '1', 'alertas': [{'status': 'Inativo Intransitável', 'sentido': 'UNICO', 'referencia': 'PC QUATORZE BIS', 'horario': {'inicio': '19:47', 'final': '20:09'}, 'logradouro': 'R MANOEL DUTRA'}]}}, {'zona': 'Zona Oeste', 'info': {'bairro': 'Lapa', 'ponto': '2', 'alertas': [{'status': 'Inativo Transitável', 'sentido': 'MARGINAL/POMPEIA', 'referencia': 'R PALESTRA ITALIA', 'horario': {'inicio': '20:07', 'final': '21:00'}, 'logradouro': 'AV POMPEIA'}, {'status': 'Inativo Intransitável', 'sentido': 'A SENNA/CASTELO B - EXP', 'referencia': 'PTE ATTILIO FONTANA', 'horario': {'inicio': '22:45', 'final': '02:27'}, 'logradouro': 'MARGINAL TIETE'}]}}, {'zona': 'Zona Sul', 'info': {'bairro': 'Santo Amaro', 'ponto': '1', 'alertas': [{'status': 'Inativo Intransitável', 'sentido': 'CENTRO/BAIRRO', 'referencia': 'AV ROQUE PETRONI JUNIOR', 'horario': {'inicio': '23:51', 'final': '01:56'}, 'logradouro': 'AV SANTO AMARO'}]}}]"]

# %%
df['Date'] = date

# %%
df['Data'] = data

# %%
df
# Out:
#          Date                                               Data
# 0  2023-09-02  [{'zona': 'Centro', 'info': {'bairro': 'Sé', '...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1 non-null      object
#  1   Data    1 non-null      object
# dtypes: object(2)
# memory usage: 144.0+ bytes

# %%
df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
df
# Out:
# <ipython-input-85-b61fe1a0c495>:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['Date'] = pd.to_datetime(df['Date'], infer_datetime_format=True)
#         Date                                               Data
# 0 2023-09-02  [{'zona': 'Centro', 'info': {'bairro': 'Sé', '...

# %%
import ast

# %%
astdata = ast.literal_eval(df['Data'][0])

# %%
astdata
# Out:
# [{'zona': 'Centro',
#   'info': {'bairro': 'Sé',
#    'ponto': '1',
#    'alertas': [{'status': 'Inativo Intransitável',
#      'sentido': 'UNICO',
#      'referencia': 'PC QUATORZE BIS',
#      'horario': {'inicio': '19:47', 'final': '20:09'},
#      'logradouro': 'R MANOEL DUTRA'}]}},
#  {'zona': 'Zona Oeste',
#   'info': {'bairro': 'Lapa',
#    'ponto': '2',
#    'alertas': [{'status': 'Inativo Transitável',
#      'sentido': 'MARGINAL/POMPEIA',
#      'referencia': 'R PALESTRA ITALIA',
#      'horario': {'inicio': '20:07', 'final': '21:00'},
#      'logradouro': 'AV POMPEIA'},
#     {'status': 'Inativo Intransitável',
#      'sentido': 'A SENNA/CASTELO B - EXP',
#      'referencia': 'PTE ATTILIO FONTANA',
#      'horario': {'inicio': '22:45', 'final': '02:27'},
#      'logradouro': 'MARGINAL TIETE'}]}},
#  {'zona': 'Zona Sul',
#   'info': {'bairro': 'Santo Amaro',
#    'ponto': '1',
#    'alertas': [{'status': 'Inativo Intransitável',
#      'sentido': 'CENTRO/BAIRRO',
# ...

# %%
type(astdata)
# Out:
# list

# %%
itemastdata = astdata[1]
itemastdata
# Out:
# {'zona': 'Zona Oeste',
#  'info': {'bairro': 'Lapa',
#   'ponto': '2',
#   'alertas': [{'status': 'Inativo Transitável',
#     'sentido': 'MARGINAL/POMPEIA',
#     'referencia': 'R PALESTRA ITALIA',
#     'horario': {'inicio': '20:07', 'final': '21:00'},
#     'logradouro': 'AV POMPEIA'},
#    {'status': 'Inativo Intransitável',
#     'sentido': 'A SENNA/CASTELO B - EXP',
#     'referencia': 'PTE ATTILIO FONTANA',
#     'horario': {'inicio': '22:45', 'final': '02:27'},
#     'logradouro': 'MARGINAL TIETE'}]}}

# %%
type(itemastdata)
# Out:
# dict

# %%
itemastdata.keys()
# Out:
# dict_keys(['zona', 'info'])

# %%
type(itemastdata['info']['alertas'])
# Out:
# list

# %%
df.loc[0]['Data']
# Out:
# "[{'zona': 'Centro', 'info': {'bairro': 'Sé', 'ponto': '1', 'alertas': [{'status': 'Inativo Intransitável', 'sentido': 'UNICO', 'referencia': 'PC QUATORZE BIS', 'horario': {'inicio': '19:47', 'final': '20:09'}, 'logradouro': 'R MANOEL DUTRA'}]}}, {'zona': 'Zona Oeste', 'info': {'bairro': 'Lapa', 'ponto': '2', 'alertas': [{'status': 'Inativo Transitável', 'sentido': 'MARGINAL/POMPEIA', 'referencia': 'R PALESTRA ITALIA', 'horario': {'inicio': '20:07', 'final': '21:00'}, 'logradouro': 'AV POMPEIA'}, {'status': 'Inativo Intransitável', 'sentido': 'A SENNA/CASTELO B - EXP', 'referencia': 'PTE ATTILIO FONTANA', 'horario': {'inicio': '22:45', 'final': '02:27'}, 'logradouro': 'MARGINAL TIETE'}]}}, {'zona': 'Zona Sul', 'info': {'bairro': 'Santo Amaro', 'ponto': '1', 'alertas': [{'status': 'Inativo Intransitável', 'sentido': 'CENTRO/BAIRRO', 'referencia': 'AV ROQUE PETRONI JUNIOR', 'horario': {'inicio': '23:51', 'final': '01:56'}, 'logradouro': 'AV SANTO AMARO'}]}}]"

# %%
novodf = pd.DataFrame()

# %%
novodf['Dia'] = []
novodf['Zona'] = []
novodf['Bairro'] = []
novodf['Ponto'] = []
novodf['Status'] = []
novodf['Sentido'] = []
novodf['Referencia'] = []
novodf['HorarioInicio'] = []
novodf['HorarioFinal'] = []
novodf['Logradouro'] = []
novodf
# Out:
# Empty DataFrame
# Columns: [Dia, Zona, Bairro, Ponto, Status, Sentido, Referencia, HorarioInicio, HorarioFinal, Logradouro]
# Index: []

# %%
for i in range(len(df)):
  astdata = ast.literal_eval(df['Data'][i])
  for itemastdata in astdata:
    for alerta in itemastdata.get('info').get('alertas'):
      linha = []
      linha.append(df['Date'][i])
      linha.append(itemastdata.get('zona'))
      linha.append(itemastdata.get('info').get('bairro'))
      linha.append(itemastdata.get('info').get('ponto'))
      linha.append(alerta.get('status'))
      linha.append(alerta.get('sentido'))
      linha.append(alerta.get('referencia'))
      linha.append(alerta.get('horario').get('inicio'))
      linha.append(alerta.get('horario').get('final'))
      linha.append(alerta.get('logradouro'))
      novodf.loc[len(novodf)]=linha

# %%
novodf
# Out:
#          Dia        Zona       Bairro Ponto                 Status  \
# 0 2023-09-02      Centro           Sé     1  Inativo Intransitável
# 1 2023-09-02  Zona Oeste         Lapa     2    Inativo Transitável
# 2 2023-09-02  Zona Oeste         Lapa     2  Inativo Intransitável
# 3 2023-09-02    Zona Sul  Santo Amaro     1  Inativo Intransitável
#
#                    Sentido               Referencia HorarioInicio  \
# 0                    UNICO          PC QUATORZE BIS         19:47
# 1         MARGINAL/POMPEIA        R PALESTRA ITALIA         20:07
# 2  A SENNA/CASTELO B - EXP      PTE ATTILIO FONTANA         22:45
# 3            CENTRO/BAIRRO  AV ROQUE PETRONI JUNIOR         23:51
#
#   HorarioFinal      Logradouro
# 0        20:09  R MANOEL DUTRA
# 1        21:00      AV POMPEIA
# 2        02:27  MARGINAL TIETE
# 3        01:56  AV SANTO AMARO
