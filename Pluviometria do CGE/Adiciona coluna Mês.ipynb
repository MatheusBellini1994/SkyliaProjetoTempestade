# %%
import pandas as pd

# %%
for i in range(1,13):
  df = pd.read_csv('PluviometriaZS2023'+f'{i}'+'.csv')
  df['Mês'] = [(i) for x in df['Dia']]
  df = df[['Cód. Bairros','Nome Bairros','Dia','Mês','Pluviometria']]
  df.to_csv('PluviometriaComMes2023'+f'{i}'+'.csv', encoding='utf-8', index=False)
