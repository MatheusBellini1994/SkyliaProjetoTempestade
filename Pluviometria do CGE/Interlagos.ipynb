# %% [markdown]
# #2018

# %%
Interlagos2018 = pd.read_csv('2018.CSV', sep=';', encoding='latin1', decimal=',')

# %%
#Temp. Ins. (C),Umi. Ins. (%),Vel. Vento (m/s),Raj. Vento (m/s),Chuva (mm),num_ocorrencias

# %%
Interlagos2018
# Out:
#      DATA (YYYY-MM-DD) HORA (UTC)  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0           2018-03-14      00:00                           -9999.0
# 1           2018-03-14      01:00                           -9999.0
# 2           2018-03-14      02:00                           -9999.0
# 3           2018-03-14      03:00                           -9999.0
# 4           2018-03-14      04:00                           -9999.0
# ...                ...        ...                               ...
# 7027        2018-12-31      19:00                               0.0
# 7028        2018-12-31      20:00                               0.0
# 7029        2018-12-31      21:00                               0.0
# 7030        2018-12-31      22:00                               0.0
# 7031        2018-12-31      23:00                               0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                               -9999.0
# ...

# %%
Interlagos2018 = Interlagos2018[39:]

# %%
Interlagos2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6993 entries, 39 to 7031
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   DATA (YYYY-MM-DD)                                      6993 non-null   object
#  1   HORA (UTC)                                             6993 non-null   object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       6993 non-null   float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  6993 non-null   float64
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        6993 non-null   float64
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       6993 non-null   float64
#  6   RADIACAO GLOBAL (KJ/m²)                                6993 non-null   float64
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           6993 non-null   float64
# ...

# %%
#Temp. Ins. (C), Umi. Ins. (%), Vel. Vento (m/s), Raj. Vento (m/s), Chuva (mm), num_ocorrencias

# %%
Interlagos2018.rename(columns={'DATA (YYYY-MM-DD)':'Data',
                               'HORA (UTC)':'Hora',
                               'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)':'Temp. Ins. (C)',
                               'UMIDADE RELATIVA DO AR, HORARIA (%)':'Umi. Ins. (%)',
                               'VENTO, VELOCIDADE HORARIA (m/s)':'Vel. Vento (m/s)',
                               'VENTO, RAJADA MAXIMA (m/s)':'Raj. Vento (m/s)',
                               'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)':'Chuva (mm)'},
                      inplace=True,
                      errors='raise')
# Out:
# <ipython-input-140-792da7ec5a7a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Interlagos2018.rename(columns={'DATA (YYYY-MM-DD)':'Data',

# %%
Interlagos2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6993 entries, 39 to 7031
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Data                                                   6993 non-null   object
#  1   Hora                                                   6993 non-null   object
#  2   Chuva (mm)                                             6993 non-null   float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  6993 non-null   float64
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        6993 non-null   float64
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       6993 non-null   float64
#  6   RADIACAO GLOBAL (KJ/m²)                                6993 non-null   float64
#  7   Temp. Ins. (C)                                         6993 non-null   float64
# ...

# %%
Interlagos2018 = Interlagos2018[['Data',
                                 'Hora',
                                 'Temp. Ins. (C)',
                                 'Umi. Ins. (%)',
                                 'Vel. Vento (m/s)',
                                 'Raj. Vento (m/s)',
                                 'Chuva (mm)']]

# %%
Interlagos2018
# Out:
#             Data   Hora  Temp. Ins. (C)  Umi. Ins. (%)  Vel. Vento (m/s)  \
# 39    2018-03-15  15:00            28.6             59               4.0
# 40    2018-03-15  16:00            29.5             57               3.4
# 41    2018-03-15  17:00            30.7             56               2.7
# 42    2018-03-15  18:00            31.2             52               2.8
# 43    2018-03-15  19:00            30.1             56               2.4
# ...          ...    ...             ...            ...               ...
# 7027  2018-12-31  19:00            25.3             71               3.9
# 7028  2018-12-31  20:00            24.8             72               4.0
# 7029  2018-12-31  21:00            23.2             76               4.2
# 7030  2018-12-31  22:00            22.1             83               2.9
# 7031  2018-12-31  23:00            21.4             87               2.8
#
#       Raj. Vento (m/s)  Chuva (mm)
# 39                 8.7         0.2
# ...

# %%
Interlagos2018['Data'] = pd.to_datetime(Interlagos2018['Data']+' '+Interlagos2018['Hora'])
Interlagos2018
# Out:
# <ipython-input-144-24f663328131>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Interlagos2018['Data'] = pd.to_datetime(Interlagos2018['Data']+' '+Interlagos2018['Hora'])
#                     Data   Hora  Temp. Ins. (C)  Umi. Ins. (%)  \
# 39   2018-03-15 15:00:00  15:00            28.6             59
# 40   2018-03-15 16:00:00  16:00            29.5             57
# 41   2018-03-15 17:00:00  17:00            30.7             56
# 42   2018-03-15 18:00:00  18:00            31.2             52
# 43   2018-03-15 19:00:00  19:00            30.1             56
# ...                  ...    ...             ...            ...
# 7027 2018-12-31 19:00:00  19:00            25.3             71
# ...

# %%
Interlagos2018 = Interlagos2018[['Data',
                                 'Temp. Ins. (C)',
                                 'Umi. Ins. (%)',
                                 'Vel. Vento (m/s)',
                                 'Raj. Vento (m/s)',
                                 'Chuva (mm)']]

# %%
Interlagos2018
# Out:
#                     Data  Temp. Ins. (C)  Umi. Ins. (%)  Vel. Vento (m/s)  \
# 39   2018-03-15 15:00:00            28.6             59               4.0
# 40   2018-03-15 16:00:00            29.5             57               3.4
# 41   2018-03-15 17:00:00            30.7             56               2.7
# 42   2018-03-15 18:00:00            31.2             52               2.8
# 43   2018-03-15 19:00:00            30.1             56               2.4
# ...                  ...             ...            ...               ...
# 7027 2018-12-31 19:00:00            25.3             71               3.9
# 7028 2018-12-31 20:00:00            24.8             72               4.0
# 7029 2018-12-31 21:00:00            23.2             76               4.2
# 7030 2018-12-31 22:00:00            22.1             83               2.9
# 7031 2018-12-31 23:00:00            21.4             87               2.8
#
#       Raj. Vento (m/s)  Chuva (mm)
# 39                 8.7         0.2
# ...

# %%
Interlagos2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6993 entries, 39 to 7031
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Data              6993 non-null   datetime64[ns]
#  1   Temp. Ins. (C)    6993 non-null   float64
#  2   Umi. Ins. (%)     6993 non-null   int64
#  3   Vel. Vento (m/s)  6993 non-null   float64
#  4   Raj. Vento (m/s)  6993 non-null   float64
#  5   Chuva (mm)        6993 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 327.9 KB

# %% [markdown]
# #2019

# %%
Interlagos2019 = pd.read_csv('2019.CSV', sep=';', encoding='latin1', decimal=',')

# %%
#Temp. Ins. (C),Umi. Ins. (%),Vel. Vento (m/s),Raj. Vento (m/s),Chuva (mm),num_ocorrencias

# %%
Interlagos2019
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2019/01/01  0000 UTC                               0.0
# 1     2019/01/01  0100 UTC                               0.0
# 2     2019/01/01  0200 UTC                               0.0
# 3     2019/01/01  0300 UTC                               0.0
# 4     2019/01/01  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8755  2019/12/31  1900 UTC                               0.0
# 8756  2019/12/31  2000 UTC                               0.0
# 8757  2019/12/31  2100 UTC                               0.0
# 8758  2019/12/31  2200 UTC                               0.0
# 8759  2019/12/31  2300 UTC                               0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 926.8
# 1                                                 927.2
# 2                                                 926.9
# ...

# %%
Interlagos2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Data                                                   8760 non-null   object
#  1   Hora UTC                                               8760 non-null   object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       8760 non-null   float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  8760 non-null   float64
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        8760 non-null   float64
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       8760 non-null   float64
#  6   RADIACAO GLOBAL (KJ/m²)                                4759 non-null   float64
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           8760 non-null   float64
# ...

# %%
#Temp. Ins. (C), Umi. Ins. (%), Vel. Vento (m/s), Raj. Vento (m/s), Chuva (mm), num_ocorrencias

# %%
Interlagos2019.rename(columns={'Hora UTC':'Hora',
                               'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)':'Temp. Ins. (C)',
                               'UMIDADE RELATIVA DO AR, HORARIA (%)':'Umi. Ins. (%)',
                               'VENTO, VELOCIDADE HORARIA (m/s)':'Vel. Vento (m/s)',
                               'VENTO, RAJADA MAXIMA (m/s)':'Raj. Vento (m/s)',
                               'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)':'Chuva (mm)'},
                      inplace=True,
                      errors='raise')

# %%
Interlagos2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Data                                                   8760 non-null   object
#  1   Hora                                                   8760 non-null   object
#  2   Chuva (mm)                                             8760 non-null   float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  8760 non-null   float64
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        8760 non-null   float64
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       8760 non-null   float64
#  6   RADIACAO GLOBAL (KJ/m²)                                4759 non-null   float64
#  7   Temp. Ins. (C)                                         8760 non-null   float64
# ...

# %%
Interlagos2019 = Interlagos2019[['Data',
                                 'Hora',
                                 'Temp. Ins. (C)',
                                 'Umi. Ins. (%)',
                                 'Vel. Vento (m/s)',
                                 'Raj. Vento (m/s)',
                                 'Chuva (mm)']]

# %%
Interlagos2019
# Out:
#             Data      Hora  Temp. Ins. (C)  Umi. Ins. (%)  Vel. Vento (m/s)  \
# 0     2019/01/01  0000 UTC            21.5           87.0               2.3
# 1     2019/01/01  0100 UTC            21.1           87.0               2.1
# 2     2019/01/01  0200 UTC            20.7           90.0               1.6
# 3     2019/01/01  0300 UTC            20.5           92.0               1.7
# 4     2019/01/01  0400 UTC            20.7           93.0               1.9
# ...          ...       ...             ...            ...               ...
# 8755  2019/12/31  1900 UTC            25.1           78.0               3.9
# 8756  2019/12/31  2000 UTC            23.7           81.0               2.6
# 8757  2019/12/31  2100 UTC            23.3           83.0               2.5
# 8758  2019/12/31  2200 UTC            22.6           87.0               1.9
# 8759  2019/12/31  2300 UTC            22.0           90.0               1.3
#
#       Raj. Vento (m/s)  Chuva (mm)
# ...

# %%
for i in range(len(Interlagos2019)):
  Interlagos2019['Hora'][i] = Interlagos2019['Hora'][i][:4]
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# <ipython-input-157-f948f27ae598>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Interlagos2019['Hora'][i] = Interlagos2019['Hora'][i][:4]
# <ipython-input-157-f948f27ae598>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Interlagos2019['Hora'][i] = Interlagos2019['Hora'][i][:4]
# <ipython-input-157-f948f27ae598>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
Interlagos2019['Data'] = pd.to_datetime(Interlagos2019['Data']+' '+Interlagos2019['Hora'])
Interlagos2019
# Out:
# <ipython-input-158-104ced6580ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Interlagos2019['Data'] = pd.to_datetime(Interlagos2019['Data']+' '+Interlagos2019['Hora'], utc=False)
#                     Data  Hora  Temp. Ins. (C)  Umi. Ins. (%)  \
# 0    2019-01-01 00:00:00  0000            21.5           87.0
# 1    2019-01-01 01:00:00  0100            21.1           87.0
# 2    2019-01-01 02:00:00  0200            20.7           90.0
# 3    2019-01-01 03:00:00  0300            20.5           92.0
# 4    2019-01-01 04:00:00  0400            20.7           93.0
# ...                  ...   ...             ...            ...
# 8755 2019-12-31 19:00:00  1900            25.1           78.0
# ...

# %%
Interlagos2019 = Interlagos2019[['Data',
                                 'Temp. Ins. (C)',
                                 'Umi. Ins. (%)',
                                 'Vel. Vento (m/s)',
                                 'Raj. Vento (m/s)',
                                 'Chuva (mm)']]

# %%
Interlagos2019
# Out:
#                     Data  Temp. Ins. (C)  Umi. Ins. (%)  Vel. Vento (m/s)  \
# 0    2019-01-01 00:00:00            21.5           87.0               2.3
# 1    2019-01-01 01:00:00            21.1           87.0               2.1
# 2    2019-01-01 02:00:00            20.7           90.0               1.6
# 3    2019-01-01 03:00:00            20.5           92.0               1.7
# 4    2019-01-01 04:00:00            20.7           93.0               1.9
# ...                  ...             ...            ...               ...
# 8755 2019-12-31 19:00:00            25.1           78.0               3.9
# 8756 2019-12-31 20:00:00            23.7           81.0               2.6
# 8757 2019-12-31 21:00:00            23.3           83.0               2.5
# 8758 2019-12-31 22:00:00            22.6           87.0               1.9
# 8759 2019-12-31 23:00:00            22.0           90.0               1.3
#
#       Raj. Vento (m/s)  Chuva (mm)
# 0                  5.9         0.0
# ...

# %%
Interlagos2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Data              8760 non-null   datetime64[ns]
#  1   Temp. Ins. (C)    8760 non-null   float64
#  2   Umi. Ins. (%)     8753 non-null   float64
#  3   Vel. Vento (m/s)  8760 non-null   float64
#  4   Raj. Vento (m/s)  8760 non-null   float64
#  5   Chuva (mm)        8760 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 410.8 KB

# %% [markdown]
# #2020

# %%
Interlagos2020 = pd.read_csv('2020.CSV', sep=';', encoding='latin1', decimal=',')

# %%
#Temp. Ins. (C),Umi. Ins. (%),Vel. Vento (m/s),Raj. Vento (m/s),Chuva (mm),num_ocorrencias

# %%
Interlagos2020
# Out:
#             Data  Hora UTC  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0     2020/01/01  0000 UTC                               0.0
# 1     2020/01/01  0100 UTC                               0.0
# 2     2020/01/01  0200 UTC                               0.0
# 3     2020/01/01  0300 UTC                               0.0
# 4     2020/01/01  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8779  2020/12/31  1900 UTC                               0.0
# 8780  2020/12/31  2000 UTC                               0.0
# 8781  2020/12/31  2100 UTC                               0.8
# 8782  2020/12/31  2200 UTC                               9.2
# 8783  2020/12/31  2300 UTC                               0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                                 923.1
# 1                                                 923.7
# 2                                                 923.6
# ...

# %%
Interlagos2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Data                                                   8784 non-null   object
#  1   Hora UTC                                               8784 non-null   object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       8781 non-null   float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  8782 non-null   float64
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        8782 non-null   float64
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       8782 non-null   float64
#  6   RADIACAO GLOBAL (Kj/m²)                                4769 non-null   float64
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           8782 non-null   float64
# ...

# %%
#Temp. Ins. (C), Umi. Ins. (%), Vel. Vento (m/s), Raj. Vento (m/s), Chuva (mm), num_ocorrencias

# %%
Interlagos2020.rename(columns={'Hora UTC':'Hora',
                               'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)':'Temp. Ins. (C)',
                               'UMIDADE RELATIVA DO AR, HORARIA (%)':'Umi. Ins. (%)',
                               'VENTO, VELOCIDADE HORARIA (m/s)':'Vel. Vento (m/s)',
                               'VENTO, RAJADA MAXIMA (m/s)':'Raj. Vento (m/s)',
                               'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)':'Chuva (mm)'},
                      inplace=True,
                      errors='raise')

# %%
Interlagos2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 20 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Data                                                   8784 non-null   object
#  1   Hora                                                   8784 non-null   object
#  2   Chuva (mm)                                             8781 non-null   float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  8782 non-null   float64
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        8782 non-null   float64
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       8782 non-null   float64
#  6   RADIACAO GLOBAL (Kj/m²)                                4769 non-null   float64
#  7   Temp. Ins. (C)                                         8782 non-null   float64
# ...

# %%
Interlagos2020 = Interlagos2020[['Data',
                                 'Hora',
                                 'Temp. Ins. (C)',
                                 'Umi. Ins. (%)',
                                 'Vel. Vento (m/s)',
                                 'Raj. Vento (m/s)',
                                 'Chuva (mm)']]

# %%
Interlagos2020
# Out:
#             Data      Hora  Temp. Ins. (C)  Umi. Ins. (%)  Vel. Vento (m/s)  \
# 0     2020/01/01  0000 UTC            22.0           92.0               0.4
# 1     2020/01/01  0100 UTC            22.1           92.0               0.9
# 2     2020/01/01  0200 UTC            23.2           82.0               1.2
# 3     2020/01/01  0300 UTC            23.3           79.0               1.2
# 4     2020/01/01  0400 UTC            22.9           79.0               0.6
# ...          ...       ...             ...            ...               ...
# 8779  2020/12/31  1900 UTC            24.5           71.0               2.2
# 8780  2020/12/31  2000 UTC            23.9           75.0               1.3
# 8781  2020/12/31  2100 UTC            21.9           94.0               0.8
# 8782  2020/12/31  2200 UTC            20.4           97.0               1.7
# 8783  2020/12/31  2300 UTC            19.9           97.0               1.9
#
#       Raj. Vento (m/s)  Chuva (mm)
# ...

# %%
for i in range(len(Interlagos2020)):
  Interlagos2020['Hora'][i] = Interlagos2020['Hora'][i][:4]
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# <ipython-input-171-b62f240d117e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Interlagos2020['Hora'][i] = Interlagos2020['Hora'][i][:4]
# <ipython-input-171-b62f240d117e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Interlagos2020['Hora'][i] = Interlagos2020['Hora'][i][:4]
# <ipython-input-171-b62f240d117e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
Interlagos2019['Data'] = pd.to_datetime(Interlagos2019['Data']+' '+Interlagos2019['Hora'])
Interlagos2019
# Out:
# <ipython-input-158-104ced6580ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Interlagos2019['Data'] = pd.to_datetime(Interlagos2019['Data']+' '+Interlagos2019['Hora'], utc=False)
#                     Data  Hora  Temp. Ins. (C)  Umi. Ins. (%)  \
# 0    2019-01-01 00:00:00  0000            21.5           87.0
# 1    2019-01-01 01:00:00  0100            21.1           87.0
# 2    2019-01-01 02:00:00  0200            20.7           90.0
# 3    2019-01-01 03:00:00  0300            20.5           92.0
# 4    2019-01-01 04:00:00  0400            20.7           93.0
# ...                  ...   ...             ...            ...
# 8755 2019-12-31 19:00:00  1900            25.1           78.0
# ...

# %%
Interlagos2019 = Interlagos2019[['Data',
                                 'Temp. Ins. (C)',
                                 'Umi. Ins. (%)',
                                 'Vel. Vento (m/s)',
                                 'Raj. Vento (m/s)',
                                 'Chuva (mm)']]

# %%
Interlagos2019
# Out:
#                     Data  Temp. Ins. (C)  Umi. Ins. (%)  Vel. Vento (m/s)  \
# 0    2019-01-01 00:00:00            21.5           87.0               2.3
# 1    2019-01-01 01:00:00            21.1           87.0               2.1
# 2    2019-01-01 02:00:00            20.7           90.0               1.6
# 3    2019-01-01 03:00:00            20.5           92.0               1.7
# 4    2019-01-01 04:00:00            20.7           93.0               1.9
# ...                  ...             ...            ...               ...
# 8755 2019-12-31 19:00:00            25.1           78.0               3.9
# 8756 2019-12-31 20:00:00            23.7           81.0               2.6
# 8757 2019-12-31 21:00:00            23.3           83.0               2.5
# 8758 2019-12-31 22:00:00            22.6           87.0               1.9
# 8759 2019-12-31 23:00:00            22.0           90.0               1.3
#
#       Raj. Vento (m/s)  Chuva (mm)
# 0                  5.9         0.0
# ...

# %%
Interlagos2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Data              8760 non-null   datetime64[ns]
#  1   Temp. Ins. (C)    8760 non-null   float64
#  2   Umi. Ins. (%)     8753 non-null   float64
#  3   Vel. Vento (m/s)  8760 non-null   float64
#  4   Raj. Vento (m/s)  8760 non-null   float64
#  5   Chuva (mm)        8760 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 410.8 KB

# %%
import pandas as pd
import numpy as np
